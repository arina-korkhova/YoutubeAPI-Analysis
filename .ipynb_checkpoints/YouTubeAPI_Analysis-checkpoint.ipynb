# %%
from googleapiclient.discovery import build
from IPython.display import JSON
from dateutil import parser
import pandas as pd
import numpy as np

# Data viz packages
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
plt.rcParams['figure.figsize'] = (7,6)
sns.set_palette(palette='summer', n_colors=10)
# NLP
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
#nltk.download('stopwords')
#nltk.download('punkt')
from wordcloud import WordCloud

# %%
api_key = ''

# %%
channel_ids = ['UCAuUUnT6oDeKwE6v1NGQxug',  # TED
               'UCsT0YIqwnpJCM-mx7-gSA4Q',  # TEDx Talks
               'UCsooa4yRKGN_zEE8iknghZA',  # TED-Ed
               'UC-yTB2bUcin9mmah36sXiYA'   # TEDxYouth
              ]

# %%
api_service_name = 'youtube'
api_version = 'v3'

# Get credentials and create an API client
youtube = build(
        api_service_name, api_version, developerKey=api_key)

request = youtube.channels().list(
        part='snippet,contentDetails,statistics',
        id=','.join(channel_ids)
    )
response = request.execute()

print(response)
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'VgEgbDl2ZH4wf9B6fzdqYXM3Sqw', 'pageInfo': {'totalResults': 4, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'KXV3obi7ucuBLVYKTcyBiX3N1Sg', 'id': 'UCAuUUnT6oDeKwE6v1NGQxug', 'snippet': {'title': 'TED', 'description': "The TED Talks channel features the best talks and performances from the TED Conference, where the world's leading thinkers and doers give the talk of their lives in 18 minutes (or less). Look for talks on Technology, Entertainment and Design -- plus science, business, global issues, the arts and more. You're welcome to link to or embed these videos, forward them to others and share these ideas with people you know.\n\nTED's videos may be used for non-commercial purposes under a Creative Commons License, Attribution–Non Commercial–No Derivatives (or the CC BY – NC – ND 4.0 International) and in accordance with our TED Talks Usage Policy: https://www.ted.com/about/our-organization/our-policies-terms/ted-talks-usage-policy. For more information on using TED for commercial purposes (e.g. employee learning, in a film or online course), please submit a Media Request at https://media-requests.ted.com", 'customUrl': '@ted', 'publishedAt': '2006-12-06T23:27:08Z', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AMLnZu94pzTFiSDqYIvXn40JdctQCOxK2fnAMEy0zdL6kA=s88-c-k-c0x00ffffff-no-rj', 'width': 88, 'height': 88}, 'medium': {'url': 'https://yt3.ggpht.com/ytc/AMLnZu94pzTFiSDqYIvXn40JdctQCOxK2fnAMEy0zdL6kA=s240-c-k-c0x00ffffff-no-rj', 'width': 240, 'height': 240}, 'high': {'url': 'https://yt3.ggpht.com/ytc/AMLnZu94pzTFiSDqYIvXn40JdctQCOxK2fnAMEy0zdL6kA=s800-c-k-c0x00ffffff-no-rj', 'width': 800, 'height': 800}}, 'localized': {'title': 'TED', 'description': "The TED Talks channel features the best talks and performances from the TED Conference, where the world's leading thinkers and doers give the talk of their lives in 18 minutes (or less). Look for talks on Technology, Entertainment and Design -- plus science, business, global issues, the arts and more. You're welcome to link to or embed these videos, forward them to others and share these ideas with people you know.\n\nTED's videos may be used for non-commercial purposes under a Creative Commons License, Attribution–Non Commercial–No Derivatives (or the CC BY – NC – ND 4.0 International) and in accordance with our TED Talks Usage Policy: https://www.ted.com/about/our-organization/our-policies-terms/ted-talks-usage-policy. For more information on using TED for commercial purposes (e.g. employee learning, in a film or online course), please submit a Media Request at https://media-requests.ted.com"}, 'country': 'US'}, 'contentDetails': {'relatedPlaylists': {'likes': '', 'uploads': 'UUAuUUnT6oDeKwE6v1NGQxug'}}, 'statistics': {'viewCount': '2446199848', 'subscriberCount': '22300000', 'hiddenSubscriberCount': False, 'videoCount': '4159'}}, {'kind': 'youtube#channel', 'etag': 'mXKKkqAnmJfgmbsScSY4uiGnWs8', 'id': 'UC-yTB2bUcin9mmah36sXiYA', 'snippet': {'title': 'TEDxYouth', 'description': '', 'customUrl': '@tedxyouth', 'publishedAt': '2010-08-13T11:30:47Z', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AMLnZu8M8EdMP4rL0i8epmfw9ZKqgXnPapPtAQzzOVPD=s88-c-k-c0x00ffffff-no-rj', 'width': 88, 'height': 88}, 'medium': {'url': 'https://yt3.ggpht.com/ytc/AMLnZu8M8EdMP4rL0i8epmfw9ZKqgXnPapPtAQzzOVPD=s240-c-k-c0x00ffffff-no-rj', 'width': 240, 'height': 240}, 'high': {'url': 'https://yt3.ggpht.com/ytc/AMLnZu8M8EdMP4rL0i8epmfw9ZKqgXnPapPtAQzzOVPD=s800-c-k-c0x00ffffff-no-rj', 'width': 800, 'height': 800}}, 'localized': {'title': 'TEDxYouth', 'description': ''}}, 'contentDetails': {'relatedPlaylists': {'likes': '', 'uploads': 'UU-yTB2bUcin9mmah36sXiYA'}}, 'statistics': {'viewCount': '43990440', 'subscriberCount': '497000', 'hiddenSubscriberCount': False, 'videoCount': '4443'}}, {'kind': 'youtube#channel', 'etag': 'CosERLreVjgfXp914y2_uEdKyBw', 'id': 'UCsT0YIqwnpJCM-mx7-gSA4Q', 'snippet': {'title': 'TED ...

# %%
JSON(response)

# %% [markdown]
# # Functions

# %%
def get_channel_stats(youtube, channel_ids):
    
    """
    Params:
        youtube: build object of Youtube API
        channel_ids: list of channel IDs
    
    Returns:
        dataframe with all channel stats for each channel ID
    """
    
    all_data = []
    
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
    response = request.execute()

    # loop through items
    for item in response['items']:
        data = {'channelName': item['snippet']['title'],
                'subscribers': item['statistics']['subscriberCount'],
                'views': item['statistics']['viewCount'],
                'totalVideos': item['statistics']['videoCount'],
                'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
        }
        
        all_data.append(data)
        
    return(pd.DataFrame(all_data))

# %%
def get_video_ids(youtube, playlist_id):
    """
    Params:
        youtube: build object of Youtube API
        playlist_id: 'uploads' playlist ID, where all uploaded videos are stored
    
    Returns:
        a list of IDs of all videos on a channel
    """
    
    video_ids = []
    
    request = youtube.playlistItems().list(
        part='snippet,contentDetails',
        playlistId=playlist_id,
        maxResults = 50
    )
    response = request.execute()
    
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    while next_page_token is not None:
        request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId = playlist_id,
                    maxResults = 50,
                    pageToken = next_page_token)
        response = request.execute()

        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
def get_video_details(youtube, video_ids):
    """
    Params:
        youtube: build object of Youtube API
        video_ids: list of video IDs
    
    Returns:
        dataframe with some channel details for each video ID (for future analysis)
    """
    video_info_all = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            video_info_all.append(video_info)
    
    return pd.DataFrame(video_info_all)

# %%
channel_stats = get_channel_stats(youtube, channel_ids)
channel_stats
# Out:
#   channelName subscribers       views totalVideos                playlistId
# 0         TED    22300000  2446199848        4159  UUAuUUnT6oDeKwE6v1NGQxug
# 1  TEDx Talks    37100000  6983496637      190620  UUsT0YIqwnpJCM-mx7-gSA4Q
# 2      TED-Ed    18000000  3438215446        1998  UUsooa4yRKGN_zEE8iknghZA
# 3   TEDxYouth      497000    43990440        4443  UU-yTB2bUcin9mmah36sXiYA

# %% [markdown]
# # One channel

# %%
playlist_id = 'UUAuUUnT6oDeKwE6v1NGQxug' # TED

# %%
# Get video IDs
video_ids = get_video_ids(youtube, playlist_id)

# %%
len(video_ids)
# Out:
# 4159

# %%
# Get video details
video_df = get_video_details(youtube, video_ids)
video_df
# Out:
#          video_id channelTitle  \
# 0     8WmrJTyWydw          TED
# 1     OE7d4JNRYp0          TED
# 2     iYd60LgRCro          TED
# 3     UGdLvGbpehQ          TED
# 4     FtsthcgCInk          TED
# ...           ...          ...
# 4154  iG9CE55wbtY          TED
# 4155  gQ-cZRmHfs4          TED
# 4156  RTIY66IPjdY          TED
# 4157  Y6bbMQXQ180          TED
# 4158  gu_PQBmk-6c          TED
#
#                                                   title  \
# 0     How Indigenous Guardians Protect the Planet an...
# 1     Helping Others Makes Us Happier – But It Matte...
# 2     A Creative Approach to Community Climate Actio...
# 3     How Great Leaders Take On Uncertainty | Anjali...
# 4       Why You Should Make Useless Things @TED #shorts
# ...                                                 ...
# 4154     Do schools kill creativity? | Sir Ken Robinson
# 4155           Majora Carter: Greening the ghetto | TED
# 4156               Dean Ornish: The world's killer diet
# 4157  Secrets of success in 8 words, 3 minutes | Ric...
# 4158               If I controlled the Internet | Rives
#
#                                             description  \
# 0     "If we take care of the land, the land takes c...
# 1     Elizabeth Dunn discovers ways that people can ...
# 2     When he learned of the threat that rising sea ...
# 3     In a constantly changing world, it's impossibl...
# 4     Simone Giertz runs a YouTube channel about rob...
# ...                                                 ...
# 4154  Visit http://TED.com to get our entire library...
# 4155  In an emotionally charged talk, MacArthur-winn...
# 4156  http://www.ted.com  Stop wringing your hands o...
# 4157  http://www.ted.com  Why do people succeed? Is ...
# 4158  http://www.ted.com  How many poets could cram ...
#
#                                                    tags           publishedAt  \
# 0     [TEDTalk, TEDTalks, TED Talk, TED Talks, TED, ...  2022-12-26T12:00:03Z
# 1         [TEDTalk, TEDTalks, TED Talk, TED Talks, TED]  2022-12-23T17:00:14Z
# 2     [TEDTalk, TEDTalks, TED Talk, TED Talks, TED, ...  2022-12-23T12:00:26Z
# 3     [TEDTalk, TEDTalks, TED Talk, TED Talks, TED, ...  2022-12-22T12:00:31Z
# 4         [TEDTalk, TEDTalks, TED Talk, TED Talks, TED]  2022-12-21T17:00:11Z
# ...                                                 ...                   ...
# 4154  [Ken, Robinson, TED, TEDTalks, Talks, TED2006,...  2007-01-07T05:00:34Z
# 4155  [Majora, Carter, TED, TEDTalks, TED2006, Susta...  2007-01-07T04:18:33Z
# 4156  [Dean, Ornish, TED, Conference, TED2006, TEDTa...  2007-01-06T23:47:40Z
# 4157  [Richard St. John, Richard John, TED, TEDTalks...  2007-01-06T19:53:49Z
# 4158  [Rives, TED, TEDTalks, talks, spoken word, def...  2006-12-25T17:58:08Z
#
#      viewCount likeCount favouriteCount commentCount  duration definition  \
# 0        17745       535           None          104  PT13M57S         hd
# 1        34715      1077           None           30     PT27S         hd
# 2        23404       434           None           53  PT10M32S         hd
# 3        30695       615           None           96  PT23M16S         hd
# 4        61432      2306           None           39      PT1M         hd
# ...        ...       ...            ...          ...       ...        ...
# 4154  22034398    263020           None        12169   PT20M4S         sd
# 4155    189105      1943           None           92  PT19M16S         sd
# 4156    117486       813           None           93   PT3M35S         sd
# 4157   3195282     48609           None          725   PT3M47S         sd
# 4158    364775      3655           None          429   PT4M17S         sd
#
#      caption
# 0       true
# 1       true
# 2       true
# 3       true
# 4       true
# ...      ...
# 4154    true
# 4155    true
# 4156    true
# 4157    true
# 4158    true
#
# [4159 rows x 13 columns]

# %% [markdown]
# ## Data pre-processing

# %%
# Check for NULL values
video_df.isnull().any()
# Out:
# video_id          False
# channelTitle      False
# title             False
# description       False
# tags               True
# publishedAt       False
# viewCount         False
# likeCount          True
# favouriteCount     True
# commentCount       True
# duration          False
# definition        False
# caption           False
# dtype: bool

# %%
# Check data types
video_df.dtypes
# Out:
# video_id          object
# channelTitle      object
# title             object
# description       object
# tags              object
# publishedAt       object
# viewCount         object
# likeCount         object
# favouriteCount    object
# commentCount      object
# duration          object
# definition        object
# caption           object
# dtype: object

# %%
# Convert count columns to numeric
numeric_cols = ['viewCount', 'likeCount', 'favouriteCount', 'commentCount']
video_df[numeric_cols] = video_df[numeric_cols].apply(pd.to_numeric, errors = 'coerce', axis = 1)

# %%
# Publish day in the week
video_df['publishedAt'] = video_df['publishedAt'].apply(lambda x: parser.parse(x)) 
video_df['pushblishDayName'] = video_df['publishedAt'].apply(lambda x: x.strftime("%A"))

# %%
# convert duration to seconds
import isodate

video_df['durationSecs'] = video_df['duration'].apply(lambda x: isodate.parse_duration(x))
video_df['durationSecs'] = video_df['durationSecs'].astype('timedelta64[s]')

# %%
video_df[['durationSecs', 'duration']]
# Out:
#       durationSecs  duration
# 0            837.0  PT13M57S
# 1             27.0     PT27S
# 2            632.0  PT10M32S
# 3           1396.0  PT23M16S
# 4             60.0      PT1M
# ...            ...       ...
# 4154        1204.0   PT20M4S
# 4155        1156.0  PT19M16S
# 4156         215.0   PT3M35S
# 4157         227.0   PT3M47S
# 4158         257.0   PT4M17S
#
# [4159 rows x 2 columns]

# %%
# Add tag count
video_df['tagCount'] = video_df['tags'].apply(lambda x: 0 if x is None else len(x))

# %%
# Add interactions count = number of likes + number of comments
video_df['interactionsCount'] = video_df['likeCount']+video_df['commentCount']

# %%
video_df
# Out:
#          video_id channelTitle  \
# 0     8WmrJTyWydw          TED
# 1     OE7d4JNRYp0          TED
# 2     iYd60LgRCro          TED
# 3     UGdLvGbpehQ          TED
# 4     FtsthcgCInk          TED
# ...           ...          ...
# 4154  iG9CE55wbtY          TED
# 4155  gQ-cZRmHfs4          TED
# 4156  RTIY66IPjdY          TED
# 4157  Y6bbMQXQ180          TED
# 4158  gu_PQBmk-6c          TED
#
#                                                   title  \
# 0     How Indigenous Guardians Protect the Planet an...
# 1     Helping Others Makes Us Happier – But It Matte...
# 2     A Creative Approach to Community Climate Actio...
# 3     How Great Leaders Take On Uncertainty | Anjali...
# 4       Why You Should Make Useless Things @TED #shorts
# ...                                                 ...
# 4154     Do schools kill creativity? | Sir Ken Robinson
# 4155           Majora Carter: Greening the ghetto | TED
# 4156               Dean Ornish: The world's killer diet
# 4157  Secrets of success in 8 words, 3 minutes | Ric...
# 4158               If I controlled the Internet | Rives
#
#                                             description  \
# 0     "If we take care of the land, the land takes c...
# 1     Elizabeth Dunn discovers ways that people can ...
# 2     When he learned of the threat that rising sea ...
# 3     In a constantly changing world, it's impossibl...
# 4     Simone Giertz runs a YouTube channel about rob...
# ...                                                 ...
# 4154  Visit http://TED.com to get our entire library...
# 4155  In an emotionally charged talk, MacArthur-winn...
# 4156  http://www.ted.com  Stop wringing your hands o...
# 4157  http://www.ted.com  Why do people succeed? Is ...
# 4158  http://www.ted.com  How many poets could cram ...
#
#                                                    tags  \
# 0     [TEDTalk, TEDTalks, TED Talk, TED Talks, TED, ...
# 1         [TEDTalk, TEDTalks, TED Talk, TED Talks, TED]
# 2     [TEDTalk, TEDTalks, TED Talk, TED Talks, TED, ...
# 3     [TEDTalk, TEDTalks, TED Talk, TED Talks, TED, ...
# 4         [TEDTalk, TEDTalks, TED Talk, TED Talks, TED]
# ...                                                 ...
# 4154  [Ken, Robinson, TED, TEDTalks, Talks, TED2006,...
# 4155  [Majora, Carter, TED, TEDTalks, TED2006, Susta...
# 4156  [Dean, Ornish, TED, Conference, TED2006, TEDTa...
# 4157  [Richard St. John, Richard John, TED, TEDTalks...
# 4158  [Rives, TED, TEDTalks, talks, spoken word, def...
#
#                    publishedAt   viewCount  likeCount  favouriteCount  \
# 0    2022-12-26 12:00:03+00:00     17745.0      535.0             NaN
# 1    2022-12-23 17:00:14+00:00     34715.0     1077.0             NaN
# 2    2022-12-23 12:00:26+00:00     23404.0      434.0             NaN
# 3    2022-12-22 12:00:31+00:00     30695.0      615.0             NaN
# 4    2022-12-21 17:00:11+00:00     61432.0     2306.0             NaN
# ...                        ...         ...        ...             ...
# 4154 2007-01-07 05:00:34+00:00  22034398.0   263020.0             NaN
# 4155 2007-01-07 04:18:33+00:00    189105.0     1943.0             NaN
# 4156 2007-01-06 23:47:40+00:00    117486.0      813.0             NaN
# 4157 2007-01-06 19:53:49+00:00   3195282.0    48609.0             NaN
# 4158 2006-12-25 17:58:08+00:00    364775.0     3655.0             NaN
#
#       commentCount  duration definition caption pushblishDayName  \
# 0            104.0  PT13M57S         hd    true           Monday
# 1             30.0     PT27S         hd    true           Friday
# 2             53.0  PT10M32S         hd    true           Friday
# 3             96.0  PT23M16S         hd    true         Thursday
# 4             39.0      PT1M         hd    true        Wednesday
# ...            ...       ...        ...     ...              ...
# 4154       12169.0   PT20M4S         sd    true           Sunday
# 4155          92.0  PT19M16S         sd    true           Sunday
# 4156          93.0   PT3M35S         sd    true         Saturday
# 4157         725.0   PT3M47S         sd    true         Saturday
# 4158         429.0   PT4M17S         sd    true           Monday
#
#       durationSecs  tagCount  interactionsCount
# 0            837.0        12              639.0
# 1             27.0         5             1107.0
# 2            632.0        16              487.0
# 3           1396.0        14              711.0
# 4             60.0         5             2345.0
# ...            ...       ...                ...
# 4154        1204.0        14           275189.0
# 4155        1156.0        16             2035.0
# 4156         215.0        16              906.0
# 4157         227.0        49            49334.0
# 4158         257.0        10             4084.0
#
# [4159 rows x 17 columns]

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Best performing videos

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount', ascending=False)[0:9])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))

# %% [markdown]
# ### Most comments

# %%
p = sns.barplot(x='title', y='commentCount', data = video_df.sort_values('commentCount', ascending=False)[0:9])
plt.xticks(rotation = 90) 
#p.set_xticklabels(ax.get_xticklabels(), rotation=90)
p.set(xlabel='Title', 
      ylabel='Number of Comments')
p.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))

# %% [markdown]
# ### Worst performing videos

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount', ascending=True)[0:9])
p = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
#ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))

# %% [markdown]
# ### View distribution per video

# %%
ax = sns.boxplot(data=video_df,
                 x='channelTitle', 
                 y='viewCount')
plt.yticks(np.arange(min(video_df['viewCount']), max(video_df['viewCount'])+1, 5000000.0))
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000000) + 'M'))

# %% [markdown]
# ### Views vs. likes and comments

# %%
fig, ax = plt.subplots(1,2)
sns.scatterplot(data = video_df, x = 'commentCount', y = 'viewCount', ax = ax[0])
sns.scatterplot(data = video_df, x = 'likeCount', y = 'viewCount', ax = ax[1])

plt.subplots_adjust(wspace=0.4)
ax[0].yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))
ax[0].set(xlabel='Number of Comments', 
          ylabel='Views')
ax[1].yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))
ax[1].set(xlabel='Number of Likes', 
          ylabel='Views')
# Out:
# [Text(0.5, 0, 'Number of Likes'), Text(0, 0.5, 'Views')]

# %% [markdown]
# ### Video duration

# %%
p = sns.histplot(data = video_df, x = 'durationSecs', bins=30)
p.set(xlabel='Duration in Seconds', 
      ylabel='Occurrences')
# Out:
# [Text(0.5, 0, 'Duration in Seconds'), Text(0, 0.5, 'Occurrences')]

# %% [markdown]
# ### Histogram of tag count

# %%
p = sns.histplot(data=video_df["tagCount"])
p.set(xlabel='Number of Tags Used', 
      ylabel='Occurrences')
# Out:
# [Text(0.5, 0, 'Number of Tags Used'), Text(0, 0.5, 'Occurrences')]

# %% [markdown]
# ### Title length used

# %%
p = sns.histplot(data=video_df['title'].str.len())
p.set(xlabel='Title Length', 
      ylabel='Occurrences')
# Out:
# [Text(0.5, 0, 'Title Length'), Text(0, 0.5, 'Occurrences')]

# %% [markdown]
# ### Wordcloud for video titles

# %%
stop_words = set(stopwords.words('english'))
video_df['title_no_stopwords'] = video_df['title'].apply(lambda x: [item for item in str(x).split() if item not in stop_words])

all_words = list([a for b in video_df['title_no_stopwords'].tolist() for a in b])
all_words_str = ' '.join(all_words) 

def plot_cloud(wordcloud):
    plt.figure(figsize=(30, 20))
    plt.imshow(wordcloud) 
    plt.axis('off');

wordcloud = WordCloud(width = 2000, height = 1000, random_state=1, background_color='black', 
                      colormap='viridis', collocations=False).generate(all_words_str)
plot_cloud(wordcloud)

# %% [markdown]
# ### Upload schedule

# %%
day_df = pd.DataFrame(video_df['pushblishDayName'].value_counts())
weekdays = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_df = day_df.reindex(weekdays)
ax = day_df.reset_index().plot.bar(x='index', y='pushblishDayName', rot=0)
